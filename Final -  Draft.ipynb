# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob

class TwitterClient(object):
	'''
	Generic Twitter Class for sentiment analysis.
	'''
	def __init__(self):
		'''
		Class constructor or initialization method.
		'''
		# keys and tokens from the Twitter Dev Console
		consumer_key = ckey
		consumer_secret = csecret
		access_token = atoken
		access_token_secret = asecret

		# attempt authentication
		try:
			# create OAuthHandler object
			self.auth = OAuthHandler(consumer_key, consumer_secret)
			# set access token and secret
			self.auth.set_access_token(access_token, access_token_secret)
			# create tweepy API object to fetch tweets
			self.api = tweepy.API(self.auth)
		except:
			print("Error: Authentication Failed")

	def clean_tweet(self, tweet):
		'''
		Utility function to clean tweet text by removing links, special characters
		using simple regex statements.
		'''
		return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

	def get_tweet_sentiment(self, tweet):
		'''
		Utility function to classify sentiment of passed tweet
		using textblob's sentiment method
		'''
		# create TextBlob object of passed tweet text
		analysis = TextBlob(self.clean_tweet(tweet))
		# set sentiment
		if analysis.sentiment.polarity > 0:
			return 'positive'
		elif analysis.sentiment.polarity == 0:
			return 'neutral'
		else:
			return 'negative'

	def get_tweets(self, query, count = 2000):
		'''
		Main function to fetch tweets and parse them.
		'''
		# empty list to store parsed tweets
		tweets = []

		try:
			# call twitter api to fetch tweets
			fetched_tweets = self.api.search(q = query, count = count)

			# parsing tweets one by one
			for tweet in fetched_tweets:
				# empty dictionary to store required params of a tweet
				parsed_tweet = {}

				# saving text of tweet
				parsed_tweet['text'] = tweet.text
				# saving sentiment of tweet
				parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)

				# appending parsed tweet to tweets list
				if tweet.retweet_count > 0:
					# if tweet has retweets, ensure that it is appended only once
					if parsed_tweet not in tweets:
						tweets.append(parsed_tweet)
				else:
					tweets.append(parsed_tweet)

			# return parsed tweets
			return tweets

		except tweepy.TweepError as e:
			# print error (if any)
			print("Error : " + str(e))

def main():
	# creating object of TwitterClient Class
	api = TwitterClient()
	# calling function to get tweets
  
	tweets = api.get_tweets(query = raw_input('Enter the Phrase: ') , count = 12000)

	# picking positive tweets from tweets
	ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
	# percentage of positive tweets
	print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
	# picking negative tweets from tweets
	ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
	# percentage of negative tweets
    
	print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
	# percentage of neutral tweets
	neutweets = [tweet for tweet in tweets if tweet['sentiment'] == 'neutral']
	# percentage of negative tweets
    
	print("Neutral tweets percentage: {} %".format(100*len(neutweets)/len(tweets)))

	# printing first 5 positive tweets
	print("\n\nPositive tweets:")
	for tweet in ptweets[:10]:
		print(tweet['text'])
# printing first 5 negative tweets
	print("\n\nNeutral tweets:")
	for tweet in neutweets[:10]:
		print(tweet['text'])
	# printing first 5 negative tweets
	print("\n\nNegative tweets:")
	for tweet in ntweets[:10]:
		print(tweet['text'])

if __name__ == "__main__":
	# calling main function
	main()
# Out:
# Enter the Phrase: Bakari
# Positive tweets percentage: 22 %
# Negative tweets percentage: 9 %
# Neutral tweets percentage: 68 %
#
#
# Positive tweets:
# Unless, of course, the Russian stories come directly from Don Jr. #TheResistance @Bakari_Sellers @CNN @ananavarro https://t.co/ozCQb6vXDO
# @Bakari_Sellers wow wow wow....every single thing this guy does is on video. everything.
# @Bakari_Sellers @TomPerez He's trash and I'm sure u heard about the donations at a low record ever.
# @Kid_Ali_85 Thanks bakari! 😊😊
# @Bakari_Sellers Not mike Vick he came from a good place just misspoke I feel
# RT @SethDavisHoops: ACA was a great idea when Romney did it in Mass, or when Gingrich presented it as alternative to Hillarycare. They oppo…
# @Bakari_Sellers lol that for sure.
# RT @djwallysparks: @edsbs @Bakari_Sellers @kennethwhalum @BIGKRIT The performance of it at the @HipHopAwards was even more turnt up.
#
# http…
# @laidybug45 @Bakari_Sellers That's interesting. I did not know this about the draft. Thank you for teaching me some… https://t.co/lW7DVjpy73
# @djwallysparks @edsbs @Bakari_Sellers @BIGKRIT @HipHopAwards More turned up on the album
#
#
# Neutral tweets:
# Give up basket cases , he will never learn the job.
# More evidence,this clown has no leadership acumen.Instead of inviting all senators from both parties to lunch,he invites on Republicans.Sad.
# RT @acmilan: China here they come! ✈
# Cina, stanno arrivando! ✈ https://t.co/tA2lw14dXO
# @mandjstephenson @BayLuv420 @Bakari_Sellers His continual racist attacks makes me feel obligated to call him out &amp;… https://t.co/Cl7r1mc3ne
# agora na Rádio Eixo Bakari by NOTA/Paola Antony!  https://t.co/elAMT7d7Tr
# 遊佐さんいつの間にかマッスルになってる
# @Nightmusics @Bakari_Sellers R Kelly
# @KamalaHarris @VanJones68 @Bakari_Sellers @JoyAnnReid @GOP @DNC @realDonaldTrump @EmmanuelMacron @PoppyHarlowCNN Th… https://t.co/GjqEfg4d1c
# @Bakari_Sellers STILL undefeated..😑
# @KamalaHarris @VanJones68 @Bakari_Sellers @JoyAnnReid @GOP @DNC @realDonaldTrump @EmmanuelMacron @PoppyHarlowCNN Ho… https://t.co/m0w3igwpcW
#
#
# Negative tweets:
# RT @AMAZlNGNATURE: Nope, You are Fake Horse https://t.co/SmIPsB67PV
# @oklexxo @realkenmarie STIFF
# @bananadocks @Bakari_Sellers Well..see..what had happened was..draft at 18 so people complained you can't even vote… https://t.co/m6vlNgz96O
# RT @edsbs: @Bakari_Sellers @djwallysparks @kennethwhalum @BIGKRIT holy shit @BIGKRIT on this
# @Bakari_Sellers I gotta give you that one, @Bakari_Sellers... you ain't wrong #TwitterWillGetYa #EveryTime https://t.co/pG6X9x9l7u
# @Bakari_Sellers @MatthewACherry @TheShadeRoom I worry about our country. WTF
# @Bakari_Sellers @djwallysparks @kennethwhalum @BIGKRIT holy shit @BIGKRIT on this
# @Nupe117 @cspanwj You can not live off of evil-indifference.
# RT @CathyGlaesman: @SDISBEAUTIFUL @Amy_Siskind I already don't recognize our country.   I am not proud to be an American for the first time…
